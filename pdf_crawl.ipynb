# %%
from tika import parser
import re
import os

# %%
for root, dirs, files in os.walk("data/MPB_Contents/"):
    for filename in files:

        fName = "MPB_Contents/" + filename

        content = raw['content'].replace('\n', "").replace('.', '').replace('-', '').replace('/', "").replace('+', "").replace('*', '').replace('@', "").replace(':', "").replace('~', "").replace('%', "").replace('↑', "").replace('→', '').replace('_', '').replace('Ÿ', '').replace(')', '').replace('(', '').replace(',', '').replace('년', "")

        content = re.sub('\(.+?\)', "", content)

        content = re.sub('\d+', "", content)

        content = re.sub('[a-zA-Z]', "", content)

        content = re.sub(' +', " ", content)
        
        title = filename[:-4]
        fType = filename[-4:]

        try:
            fType == ".pdf"
            print(title + '파일 변환 완료')
            f = open(title + ".txt", 'w')
            f.write(content)
            f.close()
        except Exception as ex:
            print('에러가 발생 했습니다', ex)
# Out:
# 2005_10파일 변환 완료
# 2005_12파일 변환 완료
# 2005_14파일 변환 완료
# 2005_17파일 변환 완료
# 2005_19파일 변환 완료
# 2005_2파일 변환 완료
# 2005_21파일 변환 완료
# 2005_24파일 변환 완료
# 2005_26파일 변환 완료
# 2005_4파일 변환 완료
# 2005_6파일 변환 완료
# 2005_8파일 변환 완료
# 2006_10파일 변환 완료
# 2006_12파일 변환 완료
# 2006_14파일 변환 완료
# 2006_16파일 변환 완료
# 2006_19파일 변환 완료
# 2006_2파일 변환 완료
# 2006_21파일 변환 완료
# 2006_23파일 변환 완료
# 2006_25파일 변환 완료
# 2006_4파일 변환 완료
# 2006_6파일 변환 완료
# 2006_8파일 변환 완료
# 2007_11파일 변환 완료
# 2007_13파일 변환 완료
# 2007_15파일 변환 완료
# 2007_17파일 변환 완료
# 2007_19파일 변환 완료
# 2007_2파일 변환 완료
# 2007_21파일 변환 완료
# 2007_23파일 변환 완료
# 2007_25파일 변환 완료
# 2007_4파일 변환 완료
# 2007_7파일 변환 완료
# 2007_9파일 변환 완료
# 2008_10파일 변환 완료
# 2008_12파일 변환 완료
# 2008_14파일 변환 완료
# 2008_16파일 변환 완료
# 2008_18파일 변환 완료
# 2008_2파일 변환 완료
# 2008_4파일 변환 완료
# 2008_6파일 변환 완료
# 2008_8파일 변환 완료
# 2009_12파일 변환 완료
# 2009_14파일 변환 완료
# 2009_16파일 변환 완료
# 2009_18파일 변환 완료
# 2009_2파일 변환 완료
# 2009_20파일 변환 완료
# 2009_22파일 변환 완료
# 2009_24파일 변환 완료
# 2009_26파일 변환 완료
# 2009_4파일 변환 완료
# 2009_7파일 변환 완료
# ...

# %%
content = raw['content'].replace('\n', "").replace('.', '').replace('-', '').replace('/', "").replace('+', "").replace('*', '').replace('@', "").replace(':', "").replace('~', "").replace('%', "").replace('↑', "").replace('→', '').replace('_', '').replace('Ÿ', '').replace(')', '').replace('(', '').replace(',', '').replace('년', "")

content = re.sub('\(.+?\)', "", content)

content = re.sub('\d+', "", content)

content = re.sub('[a-zA-Z]', "", content)

content = re.sub(' +', " ", content)

content
